# %%
import os
from langchain_core.chat_history import InMemoryChatMessageHistory
from langchain_core.runnables.history import RunnableWithMessageHistory
from langchain_openai import ChatOpenAI
from langchain_core.messages import HumanMessage


api_key = os.getenv("OPENAI_API_KEY")
model = ChatOpenAI(model="gpt-4o-mini")

store = {}

# %%
def get_session_history(session_id:str):
  if session_id not in store:
    store[session_id]=InMemoryChatMessageHistory()
    return store[session_id]
  

with_message_history = RunnableWithMessageHistory(model, get_session_history)

# %%
config = {"configurable":{"session_id":"abc2"}}

response = with_message_history.invoke(
  [HumanMessage(content="안녕 난 이성용이야.")],
  config=config,
)

print(response.content)
# Out:
# 안녕하세요, 이성용님! 어떻게 도와드릴까요?

# %%
# response = with_message_history.invoke(
#   [HumanMessage(content="내이름이 뭐지?")],
#   config=config,
# )

# print(response.content)

response = with_message_history.invoke(
  [HumanMessage(content="내이름이 뭐지?")],
  config=config,
)

print(response.content)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[8], line 8
#       1 # response = with_message_history.invoke(
#       2 #   [HumanMessage(content="내이름이 뭐지?")],
#       3 #   config=config,
#       4 # )
#       5
#       6 # print(response.content)
# ----> 8 response = with_message_history.invoke(
#       9   [HumanMessage(content="내이름이 뭐지?")],
#      10   config=config,
#      11 )
#      13 print(response.content)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\langchain_core\runnables\base.py:5441, in RunnableBindingBase.invoke(self, input, config, **kwargs)
#    5434 @override
#    5435 def invoke(
#    5436     self,
#    (...)   5439     **kwargs: Optional[Any],
#    5440 ) -> Output:
# -> 5441     return self.bound.invoke(
#    5442         input,
#    5443         self._merge_configs(config),
#    5444         **{**self.kwargs, **kwargs},
#    5445     )
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\langchain_core\runnables\base.py:5441, in RunnableBindingBase.invoke(self, input, config, **kwargs)
#    5434 @override
#    5435 def invoke(
#    5436     self,
#    (...)   5439     **kwargs: Optional[Any],
#    5440 ) -> Output:
# -> 5441     return self.bound.invoke(
#    5442         input,
#    5443         self._merge_configs(config),
#    5444         **{**self.kwargs, **kwargs},
#    5445     )
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\langchain_core\runnables\base.py:3047, in RunnableSequence.invoke(self, input, config, **kwargs)
#    3045 with set_config_context(config) as context:
#    3046     if i == 0:
# -> 3047         input_ = context.run(step.invoke, input_, config, **kwargs)
#    3048     else:
#    3049         input_ = context.run(step.invoke, input_, config)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\langchain_core\runnables\base.py:5441, in RunnableBindingBase.invoke(self, input, config, **kwargs)
#    5434 @override
#    5435 def invoke(
#    5436     self,
#    (...)   5439     **kwargs: Optional[Any],
#    5440 ) -> Output:
# -> 5441     return self.bound.invoke(
#    5442         input,
#    5443         self._merge_configs(config),
#    5444         **{**self.kwargs, **kwargs},
#    5445     )
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\langchain_core\runnables\base.py:4781, in RunnableLambda.invoke(self, input, config, **kwargs)
#    4767 """Invoke this Runnable synchronously.
#    4768
#    4769 Args:
#    (...)   4778     TypeError: If the Runnable is a coroutine function.
#    4779 """
#    4780 if hasattr(self, "func"):
# -> 4781     return self._call_with_config(
#    4782         self._invoke,
#    4783         input,
#    4784         ensure_config(config),
#    4785         **kwargs,
#    4786     )
#    4787 msg = "Cannot invoke a coroutine function synchronously.Use `ainvoke` instead."
#    4788 raise TypeError(msg)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\langchain_core\runnables\base.py:1938, in Runnable._call_with_config(self, func, input_, config, run_type, serialized, **kwargs)
#    1934     child_config = patch_config(config, callbacks=run_manager.get_child())
#    1935     with set_config_context(child_config) as context:
#    1936         output = cast(
#    1937             "Output",
# -> 1938             context.run(
#    1939                 call_func_with_variable_args,  # type: ignore[arg-type]
#    1940                 func,
#    1941                 input_,
#    1942                 config,
#    1943                 run_manager,
#    1944                 **kwargs,
#    1945             ),
#    1946         )
#    1947 except BaseException as e:
#    1948     run_manager.on_chain_error(e)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\langchain_core\runnables\config.py:429, in call_func_with_variable_args(func, input, config, run_manager, **kwargs)
#     427 if run_manager is not None and accepts_run_manager(func):
#     428     kwargs["run_manager"] = run_manager
# --> 429 return func(input, **kwargs)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\langchain_core\runnables\base.py:4639, in RunnableLambda._invoke(self, input_, run_manager, config, **kwargs)
#    4637                 output = chunk
#    4638 else:
# -> 4639     output = call_func_with_variable_args(
#    4640         self.func, input_, config, run_manager, **kwargs
#    4641     )
#    4642 # If the output is a Runnable, invoke it
#    4643 if isinstance(output, Runnable):
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\langchain_core\runnables\config.py:429, in call_func_with_variable_args(func, input, config, run_manager, **kwargs)
#     427 if run_manager is not None and accepts_run_manager(func):
#     428     kwargs["run_manager"] = run_manager
# --> 429 return func(input, **kwargs)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\langchain_core\runnables\history.py:519, in RunnableWithMessageHistory._enter_history(self, value, config)
#     517 def _enter_history(self, value: Any, config: RunnableConfig) -> list[BaseMessage]:
#     518     hist: BaseChatMessageHistory = config["configurable"]["message_history"]
# --> 519     messages = hist.messages.copy()
#     521     if not self.history_messages_key:
#     522         # return all messages
#     523         input_val = (
#     524             value if not self.input_messages_key else value[self.input_messages_key]
#     525         )
#
# AttributeError: 'NoneType' object has no attribute 'messages'

# %%
config = {"configurable":{"session_id":"abc3"}}

response = with_message_history.invoke(
  [HumanMessage(content="내이름이 뭐지?")],
  config=config,
)

response.content
# Out:
# '죄송하지만, 당신의 이름을 알 수 없습니다. 당신의 이름을 말씀해 주실 수 있나요?'

# %%
config = {"configurable":{"session_id":"abc2"}}

response = with_message_history.invoke(
  [HumanMessage(content="아까 우리가 무슨 얘기 했지?")],
  config=config,
)

print(response.content)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[10], line 3
#       1 config = {"configurable":{"session_id":"abc2"}}
# ----> 3 response = with_message_history.invoke(
#       4   [HumanMessage(content="아까 우리가 무슨 얘기 했지?")],
#       5   config=config,
#       6 )
#       8 print(response.content)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\langchain_core\runnables\base.py:5441, in RunnableBindingBase.invoke(self, input, config, **kwargs)
#    5434 @override
#    5435 def invoke(
#    5436     self,
#    (...)   5439     **kwargs: Optional[Any],
#    5440 ) -> Output:
# -> 5441     return self.bound.invoke(
#    5442         input,
#    5443         self._merge_configs(config),
#    5444         **{**self.kwargs, **kwargs},
#    5445     )
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\langchain_core\runnables\base.py:5441, in RunnableBindingBase.invoke(self, input, config, **kwargs)
#    5434 @override
#    5435 def invoke(
#    5436     self,
#    (...)   5439     **kwargs: Optional[Any],
#    5440 ) -> Output:
# -> 5441     return self.bound.invoke(
#    5442         input,
#    5443         self._merge_configs(config),
#    5444         **{**self.kwargs, **kwargs},
#    5445     )
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\langchain_core\runnables\base.py:3047, in RunnableSequence.invoke(self, input, config, **kwargs)
#    3045 with set_config_context(config) as context:
#    3046     if i == 0:
# -> 3047         input_ = context.run(step.invoke, input_, config, **kwargs)
#    3048     else:
#    3049         input_ = context.run(step.invoke, input_, config)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\langchain_core\runnables\base.py:5441, in RunnableBindingBase.invoke(self, input, config, **kwargs)
#    5434 @override
#    5435 def invoke(
#    5436     self,
#    (...)   5439     **kwargs: Optional[Any],
#    5440 ) -> Output:
# -> 5441     return self.bound.invoke(
#    5442         input,
#    5443         self._merge_configs(config),
#    5444         **{**self.kwargs, **kwargs},
#    5445     )
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\langchain_core\runnables\base.py:4781, in RunnableLambda.invoke(self, input, config, **kwargs)
#    4767 """Invoke this Runnable synchronously.
#    4768
#    4769 Args:
#    (...)   4778     TypeError: If the Runnable is a coroutine function.
#    4779 """
#    4780 if hasattr(self, "func"):
# -> 4781     return self._call_with_config(
#    4782         self._invoke,
#    4783         input,
#    4784         ensure_config(config),
#    4785         **kwargs,
#    4786     )
#    4787 msg = "Cannot invoke a coroutine function synchronously.Use `ainvoke` instead."
#    4788 raise TypeError(msg)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\langchain_core\runnables\base.py:1938, in Runnable._call_with_config(self, func, input_, config, run_type, serialized, **kwargs)
#    1934     child_config = patch_config(config, callbacks=run_manager.get_child())
#    1935     with set_config_context(child_config) as context:
#    1936         output = cast(
#    1937             "Output",
# -> 1938             context.run(
#    1939                 call_func_with_variable_args,  # type: ignore[arg-type]
#    1940                 func,
#    1941                 input_,
#    1942                 config,
#    1943                 run_manager,
#    1944                 **kwargs,
#    1945             ),
#    1946         )
#    1947 except BaseException as e:
#    1948     run_manager.on_chain_error(e)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\langchain_core\runnables\config.py:429, in call_func_with_variable_args(func, input, config, run_manager, **kwargs)
#     427 if run_manager is not None and accepts_run_manager(func):
#     428     kwargs["run_manager"] = run_manager
# --> 429 return func(input, **kwargs)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\langchain_core\runnables\base.py:4639, in RunnableLambda._invoke(self, input_, run_manager, config, **kwargs)
#    4637                 output = chunk
#    4638 else:
# -> 4639     output = call_func_with_variable_args(
#    4640         self.func, input_, config, run_manager, **kwargs
#    4641     )
#    4642 # If the output is a Runnable, invoke it
#    4643 if isinstance(output, Runnable):
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\langchain_core\runnables\config.py:429, in call_func_with_variable_args(func, input, config, run_manager, **kwargs)
#     427 if run_manager is not None and accepts_run_manager(func):
#     428     kwargs["run_manager"] = run_manager
# --> 429 return func(input, **kwargs)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\langchain_core\runnables\history.py:519, in RunnableWithMessageHistory._enter_history(self, value, config)
#     517 def _enter_history(self, value: Any, config: RunnableConfig) -> list[BaseMessage]:
#     518     hist: BaseChatMessageHistory = config["configurable"]["message_history"]
# --> 519     messages = hist.messages.copy()
#     521     if not self.history_messages_key:
#     522         # return all messages
#     523         input_val = (
#     524             value if not self.input_messages_key else value[self.input_messages_key]
#     525         )
#
# AttributeError: 'NoneType' object has no attribute 'messages'

# %%
config = {"configurable":{"session_id":"abc2"}}
for r in with_message_history.stream(
  [HumanMessage(content="내가 어느 나라 사람인지 맞춰보고, 그나라의 문화에 대해 말해줘")],
    config=config,
):

  print(r.content, end="|")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[11], line 2
#       1 config = {"configurable":{"session_id":"abc2"}}
# ----> 2 for r in with_message_history.stream(
#       3   [HumanMessage(content="내가 어느 나라 사람인지 맞춰보고, 그나라의 문화에 대해 말해줘")],
#       4     config=config,
#       5 ):
#       7   print(r.content, end="|")
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\langchain_core\runnables\base.py:5618, in RunnableBindingBase.stream(self, input, config, **kwargs)
#    5611 @override
#    5612 def stream(
#    5613     self,
#    (...)   5616     **kwargs: Optional[Any],
#    5617 ) -> Iterator[Output]:
# -> 5618     yield from self.bound.stream(
#    5619         input,
#    5620         self._merge_configs(config),
#    5621         **{**self.kwargs, **kwargs},
#    5622     )
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\langchain_core\runnables\base.py:5618, in RunnableBindingBase.stream(self, input, config, **kwargs)
#    5611 @override
#    5612 def stream(
#    5613     self,
#    (...)   5616     **kwargs: Optional[Any],
#    5617 ) -> Iterator[Output]:
# -> 5618     yield from self.bound.stream(
#    5619         input,
#    5620         self._merge_configs(config),
#    5621         **{**self.kwargs, **kwargs},
#    5622     )
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\langchain_core\runnables\base.py:3440, in RunnableSequence.stream(self, input, config, **kwargs)
#    3433 @override
#    3434 def stream(
#    3435     self,
#    (...)   3438     **kwargs: Optional[Any],
#    3439 ) -> Iterator[Output]:
# -> 3440     yield from self.transform(iter([input]), config, **kwargs)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\langchain_core\runnables\base.py:3426, in RunnableSequence.transform(self, input, config, **kwargs)
#    3419 @override
#    3420 def transform(
#    3421     self,
#    (...)   3424     **kwargs: Optional[Any],
#    3425 ) -> Iterator[Output]:
# -> 3426     yield from self._transform_stream_with_config(
#    3427         input,
#    3428         self._transform,
#    3429         patch_config(config, run_name=(config or {}).get("run_name") or self.name),
#    3430         **kwargs,
#    3431     )
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\langchain_core\runnables\base.py:2213, in Runnable._transform_stream_with_config(self, inputs, transformer, config, run_type, **kwargs)
#    2211 try:
#    2212     while True:
# -> 2213         chunk: Output = context.run(next, iterator)
#    2214         yield chunk
#    2215         if final_output_supported:
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\langchain_core\runnables\base.py:3388, in RunnableSequence._transform(self, inputs, run_manager, config, **kwargs)
#    3385     else:
#    3386         final_pipeline = step.transform(final_pipeline, config)
# -> 3388 yield from final_pipeline
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\langchain_core\runnables\base.py:5657, in RunnableBindingBase.transform(self, input, config, **kwargs)
#    5650 @override
#    5651 def transform(
#    5652     self,
#    (...)   5655     **kwargs: Any,
#    5656 ) -> Iterator[Output]:
# -> 5657     yield from self.bound.transform(
#    5658         input,
#    5659         self._merge_configs(config),
#    5660         **{**self.kwargs, **kwargs},
#    5661     )
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\langchain_core\runnables\base.py:4884, in RunnableLambda.transform(self, input, config, **kwargs)
#    4876 @override
#    4877 def transform(
#    4878     self,
#    (...)   4881     **kwargs: Optional[Any],
#    4882 ) -> Iterator[Output]:
#    4883     if hasattr(self, "func"):
# -> 4884         yield from self._transform_stream_with_config(
#    4885             input,
#    4886             self._transform,
#    4887             ensure_config(config),
#    4888             **kwargs,
#    4889         )
#    4890     else:
#    4891         msg = (
#    4892             "Cannot stream a coroutine function synchronously."
#    4893             "Use `astream` instead."
#    4894         )
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\langchain_core\runnables\base.py:2176, in Runnable._transform_stream_with_config(self, inputs, transformer, config, run_type, **kwargs)
#    2174 input_for_tracing, input_for_transform = tee(inputs, 2)
#    2175 # Start the input iterator to ensure the input Runnable starts before this one
# -> 2176 final_input: Optional[Input] = next(input_for_tracing, None)
#    2177 final_input_supported = True
#    2178 final_output: Optional[Output] = None
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\langchain_core\runnables\base.py:5657, in RunnableBindingBase.transform(self, input, config, **kwargs)
#    5650 @override
#    5651 def transform(
#    5652     self,
#    (...)   5655     **kwargs: Any,
#    5656 ) -> Iterator[Output]:
# -> 5657     yield from self.bound.transform(
#    5658         input,
#    5659         self._merge_configs(config),
#    5660         **{**self.kwargs, **kwargs},
#    5661     )
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\langchain_core\runnables\base.py:4884, in RunnableLambda.transform(self, input, config, **kwargs)
#    4876 @override
#    4877 def transform(
#    4878     self,
#    (...)   4881     **kwargs: Optional[Any],
#    4882 ) -> Iterator[Output]:
#    4883     if hasattr(self, "func"):
# -> 4884         yield from self._transform_stream_with_config(
#    4885             input,
#    4886             self._transform,
#    4887             ensure_config(config),
#    4888             **kwargs,
#    4889         )
#    4890     else:
#    4891         msg = (
#    4892             "Cannot stream a coroutine function synchronously."
#    4893             "Use `astream` instead."
#    4894         )
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\langchain_core\runnables\base.py:2213, in Runnable._transform_stream_with_config(self, inputs, transformer, config, run_type, **kwargs)
#    2211 try:
#    2212     while True:
# -> 2213         chunk: Output = context.run(next, iterator)
#    2214         yield chunk
#    2215         if final_output_supported:
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\langchain_core\runnables\base.py:4851, in RunnableLambda._transform(self, chunks, run_manager, config, **kwargs)
#    4849                 output = chunk
#    4850 else:
# -> 4851     output = call_func_with_variable_args(
#    4852         self.func, final, config, run_manager, **kwargs
#    4853     )
#    4855 # If the output is a Runnable, use its stream output
#    4856 if isinstance(output, Runnable):
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\langchain_core\runnables\config.py:429, in call_func_with_variable_args(func, input, config, run_manager, **kwargs)
#     427 if run_manager is not None and accepts_run_manager(func):
#     428     kwargs["run_manager"] = run_manager
# --> 429 return func(input, **kwargs)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\langchain_core\runnables\history.py:519, in RunnableWithMessageHistory._enter_history(self, value, config)
#     517 def _enter_history(self, value: Any, config: RunnableConfig) -> list[BaseMessage]:
#     518     hist: BaseChatMessageHistory = config["configurable"]["message_history"]
# --> 519     messages = hist.messages.copy()
#     521     if not self.history_messages_key:
#     522         # return all messages
#     523         input_val = (
#     524             value if not self.input_messages_key else value[self.input_messages_key]
#     525         )
#
# AttributeError: 'NoneType' object has no attribute 'messages'
