# %%
TOKEN = "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"
MODEL = {
    "text_generation": "LGAI-EXAONE/EXAONE-3.5-7.8B-Instruct",
    "translation":     "facebook/nllb-200-distilled-600M",
    "sentiment":       "beomi/KcELECTRA-base-v2022",
    "ner":             "Davlan/bert-base-multilingual-cased-ner-hrl",
    "qa":              "monologg/koelectra-base-v3-finetuned-korquad",
}

# %% [markdown]
# 텍스트 생성 : pip install transformers torch

# %%
from huggingface_hub import login
import os
from transformers import pipeline



HF_TOKEN = os.getenv("HUGGINGFACE_HUB_TOKEN")

# 텍스트 생성 파이프라인 불러오기
text_generator = pipeline(
    "text-generation",
    model="LGAI-EXAONE/EXAONE-3.5-7.8B-Instruct",
    token=HF_TOKEN,
    trust_remote_code=True,
    use_auth_token=True   # Hugging Face 토큰 필요 (환경변수에 저장했으면 True로 OK)
)

# 내가 적은 프롬프트
prompt = "궁금한 게 뭘까?"

# 텍스트 생성 실행
result = text_generator(
    prompt,
    max_length=50,       # 최대 토큰 길이
    do_sample=True,      # 샘플링 (랜덤)
    top_k=50,            # 확률 상위 50개 후보만
    top_p=0.95           # 누적 확률이 95% 되는 토큰 후보
)

print(result[0]['generated_text'])

# %% [markdown]
# text_generator = pipeline("text-generation", model="EXAONE-3.5-7.8B-Instruct")
# # 터미널 실행 : python -c "from huggingface_hub import snapshot_download; print(snapshot_download('LGAI-EXAONE/EXAONE-3.5-7.8B-Instruct', local_dir='./models/EXAONE-3.5-7.8B-Instruct'))"

# %% [markdown]
# 번역   : pip install transformers huggingface_hub

# %%
from transformers import pipeline

login(token="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")

model_name = "facebook/nllb-200-3.3B"

translator_ko_en = pipeline("translation", model=model_name, src_lang="kor_Hang", tht_lang="eng_Latn")
translator_en_ko = pipeline("translation", model=model_name, src_lang="eng_Latn", tgt_lang="kor_Hang")

korean_text = "오늘 하루가 정말 빨리 가네요"
english_translation = translator_ko_en(korean_text)
print("Korean to English:", english_translation[0]['translation_text'])


english_text = "Today really flies by"
korean_translation = translator_en_ko(english_text)
print("English to Krean:", korean_translation[0]['translation_text'])
# Out:
# C:\Users\user\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\huggingface_hub\file_download.py:143: UserWarning: `huggingface_hub` cache-system uses symlinks by default to efficiently store duplicated files but your machine does not support them in C:\Users\user\.cache\huggingface\hub\models--facebook--nllb-200-3.3B. Caching files will still work but in a degraded version that might require more space on your disk. This warning can be disabled by setting the `HF_HUB_DISABLE_SYMLINKS_WARNING` environment variable. For more details, see https://huggingface.co/docs/huggingface_hub/how-to-cache#limitations.
# To support symlinks on Windows, you either need to activate Developer Mode or to run Python as an administrator. In order to activate developer mode, see this article: https://docs.microsoft.com/en-us/windows/apps/get-started/enable-your-device-for-development
#   warnings.warn(message)
# ...

# %% [markdown]
# 감성분석 : pip install transformers

# %%
from transformers import pipeline

sentiment_analyzer_ko = pipeline("text-clssification", model = "beomi/kcELECTRA-base-v2022")


korean_text = ["이 제품 정말 마음에 들어요!", "완전 별로네요. 다시는 구매하지 않겠습니다.", "그냥 쓸만 합니다."]

result_ko = sentiment_analyzer_ko(korean_text)

for text, result in zip(korean_text, result_ko):
  print(f"Text: {text}")
  print(f"Sentiment: {result['label']}, Score: {result['score']: 4f}")
  print("-" * 40)

# %% [markdown]
# 개체명 인식 : pip install --upgrade transformers huggingface_hub torch

# %%
from transformers import pipeline

ner = pipeline(
  "ner",
  model = "Davlan/bert-baxe-multilingual-cased-ner-hrl",
  tokenizer="davlan/bert-base-multilingual-cased-ner-hrl",
  aggregation_strategy="simple"
)

text = "삼성전자는 수원에 본사를 둑 ㅗ있으며, 이재용회장이 경영을 맡고 있다."
result = ner(text)

for entity in results:
  print(f"{entity['word']} ({entity['entity_group']}) - score: {entity['score']:4f}")

# %% [markdown]
# 질의응답 : pip install --upgrade transformers huggingface_hub torch

# %%
from transformers import pipeline

ana = pipeline(
  "question-ansering",
  model = "monologg/koelectra-base-v3-finetuned-korouad",
  tokenizer="monologg/koelectra-base-v3-finetuned-korquad"
)

context = (
  "서울은 대한민국의 수도이자 특별시입니다."
  "한반도 중앙에 위치한 서울은 정치, 경제, 사회, 문화의 중심지입니다."
)

quition = "서울은 어디에 위치해 있나요?"

result = ana(question=question, context=context)

print(result)
